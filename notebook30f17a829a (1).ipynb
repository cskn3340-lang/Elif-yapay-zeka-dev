# %%
import pandas as pd
import kagglehub
import os

# 1. Veriyi indir (Konumu 'path' değişkenine kaydeder)
path = kagglehub.dataset_download("yashdev01/spotify-tracks-dataset")

# 2. İndirilen klasördeki CSV dosyasını otomatik bul
dosyalar = os.listdir(path)
csv_adi = [f for f in dosyalar if f.endswith('.csv')][0]
tam_yol = os.path.join(path, csv_adi)

# 3. Veriyi oku ve ilk 5 satırı göster
df = pd.read_csv(tam_yol)
print(f"Başarıyla yüklendi: {csv_adi}")
print(df.head())

# %%
# Sütun isimlerini listeleme
print("Veri Setindeki Özellikler (Sütunlar):")
print(df.columns.tolist())

# Ödev raporuna eklenecek örnek açıklamalar:
# - Danceability: Şarkının ritmik uygunluğu.
# - Energy: Şarkının yoğunluk ve aktivite seviyesi.
# - Popularity: 0-100 arası popülerlik puanı (Hedef değişkenimiz).

# %%
# 1. Eksik veri (boş hücre) kontrolü
print("\nEksik Veri Sayıları:")
print(df.isnull().sum())

# Eksik verileri temizleme
df = df.dropna()

# 2. Aykırı değer analizi (Örneğin: Şarkı popülerliği için)
plt.figure(figsize=(8, 5))
sns.boxplot(x=df['popularity'])
plt.title('Popülerlik Sütunu Aykırı Değer Analizi (Boxplot)')
plt.show()

# %%
# 1. Değişkenler arası ilişki (Korelasyon Isı Haritası)
plt.figure(figsize=(12, 8))
# Sadece sayısal sütunları seçerek korelasyon hesaplıyoruz
numeric_df = df.select_dtypes(include=['float64', 'int64'])
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Özellikler Arası Korelasyon Isı Haritası')
plt.show()

# 2. Enerji ve Dans Edilebilirlik arasındaki ilişki
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='energy', y='danceability', hue='popularity', alpha=0.5)
plt.title('Enerji vs Dans Edilebilirlik (Renk: Popülerlik)')
plt.show()
